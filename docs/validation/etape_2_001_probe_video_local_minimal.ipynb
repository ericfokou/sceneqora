# %% [markdown]
# # Validation Etape 2_001
#
# Ce notebook permet de verifier localement la structure d'un `VideoAsset` et la sortie JSON attendue pour le probe video minimal.

# %%
from sceneqora.domain import VideoAsset

asset = VideoAsset(
    source_path="/tmp/example.mp4",
    filename="example.mp4",
    duration_sec=12.345,
    width=1920,
    height=1080,
    fps=29.97,
    has_audio=True,
    container="mov",
)
asset.to_dict()
