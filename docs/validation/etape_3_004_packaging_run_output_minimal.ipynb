# %% [markdown]
# # Validation Ticket etape_3_004
#
# Ce notebook documente la validation manuelle minimale du ticket `etape_3_004_packaging_run_output_minimal`.
#
# Commande live cible :
#
# ```bash
# PYTHONPATH=src .venv/bin/python -m sceneqora.cli.main package-run-output /tmp/sceneqora_real_speech_output /tmp/sceneqora_real_speech_output.zip
# ```
#
# Verification attendue : l'archive `.zip` contient exactement `audio.wav`, `transcript.txt`, `transcript_segments.json` et `subtitles.srt` a la racine.
