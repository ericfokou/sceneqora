# %% [markdown]
# # Validation Ticket etape_3_002
#
# Ce notebook documente la validation manuelle minimale du ticket `etape_3_002_validation_output_pipeline_minimale`.
#
# Commande live cible :
#
# ```bash
# PYTHONPATH=src .venv/bin/python -m sceneqora.cli.main validate-local-pipeline-output /tmp/sceneqora_pipeline_output
# ```
