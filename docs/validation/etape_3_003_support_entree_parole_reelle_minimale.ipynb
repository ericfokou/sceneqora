# %% [markdown]
# # Validation Ticket etape_3_003
#
# Ce notebook documente la validation live du ticket `etape_3_003_support_entree_parole_reelle_minimale`.
#
# Option retenue : **B**.
#
# Le ticket n'ajoute pas de nouvelle CLI. Il reutilise :
# - `run-local-pipeline`
# - la validation structurelle existante
# - une validation minimale dediee au cas parole reelle dans la couche applicative.
#
# Protocole live cible :
#
# 1. obtenir localement une source video contenant reellement de la parole ;
# 2. executer le pipeline local ;
# 3. verifier que `transcript.txt` est non vide, que `transcript_segments.json` contient au moins un segment, et que `subtitles.srt` est non vide.
