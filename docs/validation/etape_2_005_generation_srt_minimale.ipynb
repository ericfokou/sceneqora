# %% [markdown]
# # Validation - etape_2_005
#
# Ce notebook sert a verifier visiblement la generation SRT minimale :
# - entree unique JSON horodate locale ;
# - sortie unique SRT locale ;
# - conversion deterministe segment -> bloc SRT ;
# - aucune ouverture vers VTT, styling ou burn-in.
