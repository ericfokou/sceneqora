# %% [markdown]
# # Validation Etape 2_002
#
# Ce notebook permet de verifier localement la structure minimale de sortie d'une extraction audio Sceneqora.

# %%
from sceneqora.domain import ExtractedAudio

result = ExtractedAudio(
    source_path="/tmp/example.mp4",
    output_path="/tmp/example.wav",
    sample_rate=16000,
    channels=1,
    format="wav",
)
result.to_dict()
