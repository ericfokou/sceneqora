# %% [markdown]
# # Validation - etape_2_003
#
# Ce notebook sert a verifier visiblement la transcription audio locale minimale :
# - entree unique WAV locale ;
# - sortie unique TXT locale ;
# - sortie CLI JSON stable ;
# - aucun glissement vers timestamps, diarisation ou sous-titres.
