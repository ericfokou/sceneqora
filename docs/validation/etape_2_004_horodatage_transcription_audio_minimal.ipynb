# %% [markdown]
# # Validation - etape_2_004
#
# Ce notebook sert a verifier visiblement l'horodatage minimal de transcription audio locale :
# - entree unique WAV locale ;
# - sortie unique JSON locale ;
# - segments limites a `start`, `end`, `text` ;
# - aucune ouverture vers SRT/VTT.
