# %% [markdown]
# # Validation - etape_3_001
#
# Ce notebook sert a verifier visiblement l'assemblage pipeline local minimal :
# - entree unique video locale ;
# - orchestration sequentielle mince ;
# - sortie locale avec `audio.wav`, `transcript.txt`, `transcript_segments.json`, `subtitles.srt` ;
# - aucune ouverture vers un moteur de pipeline generique.
