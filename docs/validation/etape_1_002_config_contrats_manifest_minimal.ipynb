# %% [markdown]
# # Validation Etape 1_002
#
# Ce notebook verifie localement le socle minimal de configuration, les contrats metier initiaux et le manifest minimal.

# %%
from sceneqora import __version__
from sceneqora.domain import JobManifest
from sceneqora.infra import load_app_config

config = load_app_config()
manifest = JobManifest.bootstrap(config=config, app_version=__version__)
config, manifest.to_dict()
