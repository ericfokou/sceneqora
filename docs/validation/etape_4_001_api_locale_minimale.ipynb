# %% [markdown]
# # Validation Ticket etape_4_001
#
# Ce notebook documente la validation manuelle minimale du ticket `etape_4_001_api_locale_minimale`.
#
# Serveur live cible :
#
# ```bash
# PYTHONPATH=src .venv/bin/python -m uvicorn sceneqora.api.app:app --host 127.0.0.1 --port 8000
# ```
#
# Checks live cibles :
#
# ```bash
# curl http://127.0.0.1:8000/health
# curl -X POST http://127.0.0.1:8000/runs \
#   -H "Content-Type: application/json" \
#   -d '{"source_path":"/tmp/sceneqora_real_speech.mp4","output_dir":"/tmp/sceneqora_api_output"}'
# ```
